# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ar=np.array([1,23,43,2,5,6,7,85,4,3,7])

# %%
ar
# Out:
# array([ 1, 23, 43,  2,  5,  6,  7, 85,  4,  3,  7])

# %%
mean = np.sum(ar)/len(ar)

# %%
mean
# Out:
# 16.90909090909091

# %%
np.mean(ar)
# Out:
# 16.90909090909091

# %%
dataset = pd.read_csv('/kaggle/input/titanics/titanic.csv')

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
dataset["Age"].mean()
# Out:
# 29.69911764705882

# %%
sns.histplot(x="Age",data=dataset,bins=[i for i in range(0,81)])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
dataset["Age"].fillna(dataset["Age"].mean(), inplace=True)

# %%
np.median(dataset["Age"])
# Out:
# 29.69911764705882

# %%
dataset["Fare"].mode()
# Out:
# 0    8.05
# Name: Fare, dtype: float64

# %%
dataset["Fare"].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64
